# %% [markdown]
# ### 1) Importar las librerias pandas, numpy y matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2) Crear un dataframe de nombre DF desde los datos que se pueden tomar desde la siguiente URL
# https://raw.githubusercontent.com/lorey/list-of-countries/master/csv/countries.csv
# Tenga en cuenta que es necesario utilizar un separador especial (punto y coma) ya que el archivo no esta separado por comas como suele ser siempre

# %%
#Creamos y cargamos el dataframe DF importandolo desde la URL dada al entorno de Colab para que sea usado en este trabajo práctico.
# Ya que el archivo esta separado por ; usamos el parámetro "delimiter" en la función pd.read_csv()
DF = pd.read_csv("https://raw.githubusercontent.com/lorey/list-of-countries/master/csv/countries.csv", delimiter=';')

# %% [markdown]
# ### 3) Visualizar las 5 primeras observaciones del dataframe DF

# %%
DF.head() # por defecto se muestran las primeros 5 observaciones del Dataframe, 
#pero si quiero ver otro número de observaciones (o porque no, tambien las primeras 5), tengo que especificar un argumento numérico a la función head(). 
#Por ejemplo, DF.head(8) mostrará las primeras 8 filas del DataFrame DF.
# Out:
#   alpha_2 alpha_3      area           capital continent currency_code  \
# 0      AD     AND     468.0  Andorra la Vella        EU           EUR
# 1      AE     ARE   82880.0         Abu Dhabi        AS           AED
# 2      AF     AFG  647500.0             Kabul        AS           AFN
# 3      AG     ATG     443.0        St. John's       NaN           XCD
# 4      AI     AIA     102.0        The Valley       NaN           XCD
#
#   currency_name eqivalent_fips_code fips  geoname_id          languages  \
# 0          Euro                 NaN   AN     3041565                 ca
# 1        Dirham                 NaN   AE      290557  ar-AE,fa,en,hi,ur
# 2       Afghani                 NaN   AF     1149361  fa-AF,ps,uz-AF,tk
# 3        Dollar                 NaN   AC     3576396              en-AG
# 4        Dollar                 NaN   AV     3573511              en-AI
#
#                    name         neighbours  numeric   phone  population  \
# 0               Andorra              ES,FR       20     376       84000
# 1  United Arab Emirates              SA,OM      784     971     4975593
# 2           Afghanistan  TM,CN,IR,TJ,PK,UZ        4      93    29121286
# 3   Antigua and Barbuda                NaN       28  +1-268       86754
# 4              Anguilla                NaN      660  +1-264       13254
#
#   postal_code_format postal_code_regex  tld
# 0              AD###  ^(?:AD)*(\d{3})$  .ad
# 1                NaN               NaN  .ae
# 2                NaN               NaN  .af
# 3                NaN               NaN  .ag
# 4                NaN               NaN  .ai

# %% [markdown]
# ### 4) Visualizar la cantidad de observaciones y caracteristicas del dataframe DF

# %%
#  Retorna una tupla que contiene el número de filas y columnas presentes en el DataFrame.
#  El atributo shape se utiliza sin paréntesis, ya que no es una función, sino un atributo del DataFrame. 
DF.shape
# Out:
# (252, 19)

# %% [markdown]
# ### 5) Visualizar los nombres de todas las caracteristicas (columnas) de dataframe DF

# %%
DF.columns.values
#Otras alternativas: 
#list(DF.columns)
#', '.join(DF.columns)
# Out:
# array(['alpha_2', 'alpha_3', 'area', 'capital', 'continent',
#        'currency_code', 'currency_name', 'eqivalent_fips_code', 'fips',
#        'geoname_id', 'languages', 'name', 'neighbours', 'numeric',
#        'phone', 'population', 'postal_code_format', 'postal_code_regex',
#        'tld'], dtype=object)

# %% [markdown]
# ### 6) Visualizar los tipos de datos de las caracteristicas (columnas) del dataframe DF

# %%
DF.dtypes
# Out:
# alpha_2                 object
# alpha_3                 object
# area                   float64
# capital                 object
# continent               object
# currency_code           object
# currency_name           object
# eqivalent_fips_code     object
# fips                    object
# geoname_id               int64
# languages               object
# name                    object
# neighbours              object
# numeric                  int64
# phone                   object
# population               int64
# postal_code_format      object
# postal_code_regex       object
# tld                     object
# dtype: object

# %% [markdown]
# ###7) Visualizar la cantidad de valores nulos que hay en cada caracteristica del dataframe DF

# %%
DF.isnull().sum()
# Out:
# alpha_2                  1
# alpha_3                  0
# area                     0
# capital                  6
# continent               42
# currency_code            1
# currency_name            1
# eqivalent_fips_code    251
# fips                     3
# geoname_id               0
# languages                3
# name                     0
# neighbours              87
# numeric                  0
# phone                    5
# population               0
# postal_code_format      98
# postal_code_regex      100
# tld                      2
# dtype: int64

# %% [markdown]
# ### 8) Crear un nuevo dataframe SUBDF formado solamente con las caracteristicas del dataframe DF que tienen menos de 50 VALORES NULOS

# %%
SUBDF = DF.dropna(thresh=len(DF)-49, axis=1) #Solución del ejercicio

# %%
#SUBDF.shape   #antes tenia 19 caracteristicas. Visualizo la cantidad de caracteristicas del dataset SUBDF

# %%
#DF.isnull().sum() #Lo uso para comparar: veo cantidad de nulos que tienen el dataset DF

# %% [markdown]
# ### 9) Visualizar cuantos valores nulos quedan aun en las caracteristicas del dataframe SUBDF

# %%
SUBDF.isnull().sum() #vemos cuantos nulos tienen las caracteristicas de SUBDF
# Out:
# alpha_2           1
# alpha_3           0
# area              0
# capital           6
# continent        42
# currency_code     1
# currency_name     1
# fips              3
# geoname_id        0
# languages         3
# name              0
# numeric           0
# phone             5
# population        0
# tld               2
# dtype: int64

# %% [markdown]
# ### 10) Eliminar todas las observaciones con valores nulos del dataframe SUBDF y poner los resultados en un nuevo dataframe de nombre SUBDF1

# %%
SUBDF.shape
# Out:
# (252, 15)

# %%
# MIS CONSIDERACIONES:
# En este ejercicio considero que el enunciado " Eliminar todas las observaciones con valores nulos del dataframe..." se refiere a que si alguna observacion tiene algun valor nulo, 
# entonces elimino dicha observacion.
#
# OBSERVACION EN LA SIGUIENTE LINEA DE CODIGO:
# - SUBDF1 es una nueva variable que apunta al mismo objeto DataFrame que la SUBDF. 
# - SUBDF1 y SUBDF estan vinculados, por lo quey cualquier modificación realizada en uno de ellos afectará al otro:
SUBDF1=SUBDF  

# OBSERVACION SOBRE LA SITUIENTE LINEA DE CODIGO:
# Elimino las filas en el dataframe SUBDF1 que contengan al menos un valor nulo. Por axis=0 la operación se realiza a lo largo del eje vertical (filas), 
# mientras que con how="any" eliminamos las filas (u observaciones) que tengan al menos un valor nulo.
SUBDF1 = SUBDF1.dropna(axis=0, how="any") # elimina aquellas que tengan algun dato vacio


#OBSERVACION FINAL:
# Tengo que mencionar que estas dos linead de codigo no modifican directamente el DataFrame SUBDF, 
# sino que se genera un nuevo DataFrame con las observaciones que cumplen la condicion.

# %%
#SUBDF.shape
# Out:
# (252, 15)

# %% [markdown]
# ### 11) Visualizar cuantas observaciones y caracteristicas tiene ahora SUBDF1

# %%
SUBDF1.shape
# Out:
# (199, 15)

# %% [markdown]
# ### 12) Verificar que no queden valores nulos en SUBDF1

# %%
SUBDF1.isnull().sum()
# Out:
# alpha_2          0
# alpha_3          0
# area             0
# capital          0
# continent        0
# currency_code    0
# currency_name    0
# fips             0
# geoname_id       0
# languages        0
# name             0
# numeric          0
# phone            0
# population       0
# tld              0
# dtype: int64

# %% [markdown]
# ### 13) Visualizar las primeras 20 observaciones de SUBDF1

# %%
SUBDF1.head(20)
# Out:
#    alpha_2 alpha_3       area              capital continent currency_code  \
# 0       AD     AND      468.0     Andorra la Vella        EU           EUR
# 1       AE     ARE    82880.0            Abu Dhabi        AS           AED
# 2       AF     AFG   647500.0                Kabul        AS           AFN
# 5       AL     ALB    28748.0               Tirana        EU           ALL
# 6       AM     ARM    29800.0              Yerevan        AS           AMD
# 7       AO     AGO  1246700.0               Luanda        AF           AOA
# 9       AR     ARG  2766890.0         Buenos Aires        SA           ARS
# 10      AS     ASM      199.0            Pago Pago        OC           USD
# 11      AT     AUT    83858.0               Vienna        EU           EUR
# 12      AU     AUS  7686850.0             Canberra        OC           AUD
# 15      AZ     AZE    86600.0                 Baku        AS           AZN
# 16      BA     BIH    51129.0             Sarajevo        EU           BAM
# 18      BD     BGD   144000.0                Dhaka        AS           BDT
# 19      BE     BEL    30510.0             Brussels        EU           EUR
# 20      BF     BFA   274200.0          Ouagadougou        AF           XOF
# 21      BG     BGR   110910.0                Sofia        EU           BGN
# 22      BH     BHR      665.0               Manama        AS           BHD
# 23      BI     BDI    27830.0            Bujumbura        AF           BIF
# 24      BJ     BEN   112620.0           Porto-Novo        AF           XOF
# 27      BN     BRN     5770.0  Bandar Seri Begawan        AS           BND
#
#    currency_name fips  geoname_id             languages  \
# 0           Euro   AN     3041565                    ca
# 1         Dirham   AE      290557     ar-AE,fa,en,hi,ur
# 2        Afghani   AF     1149361     fa-AF,ps,uz-AF,tk
# 5            Lek   AL      783754                 sq,el
# 6           Dram   AM      174982                    hy
# 7         Kwanza   AO     3351879                 pt-AO
# 9           Peso   AR     3865483  es-AR,en,it,de,fr,gn
# 10        Dollar   AQ     5880801           en-AS,sm,to
# 11          Euro   AU     2782113        de-AT,hr,hu,sl
# 12        Dollar   AS     2077456                 en-AU
# 15         Manat   AJ      587116              az,ru,hy
# 16         Marka   BK     3277605        bs,hr-BA,sr-BA
# 18          Taka   BG     1210997              bn-BD,en
# 19          Euro   BE     2802361     nl-BE,fr-BE,de-BE
# 20         Franc   UV     2361809                 fr-BF
# 21           Lev   BU      732800          bg,tr-BG,rom
# 22         Dinar   BA      290291        ar-BH,en,fa,ur
# 23         Franc   BY      433561              fr-BI,rn
# 24         Franc   BN     2395170                 fr-BJ
# 27        Dollar   BX     1820814           ms-BN,en-BN
#
#                       name  numeric   phone  population  tld
# 0                  Andorra       20     376       84000  .ad
# 1     United Arab Emirates      784     971     4975593  .ae
# 2              Afghanistan        4      93    29121286  .af
# 5                  Albania        8     355     2986952  .al
# 6                  Armenia       51     374     2968000  .am
# 7                   Angola       24     244    13068161  .ao
# 9                Argentina       32      54    41343201  .ar
# 10          American Samoa       16  +1-684       57881  .as
# 11                 Austria       40      43     8205000  .at
# 12               Australia       36      61    21515754  .au
# 15              Azerbaijan       31     994     8303512  .az
# 16  Bosnia and Herzegovina       70     387     4590000  .ba
# 18              Bangladesh       50     880   156118464  .bd
# 19                 Belgium       56      32    10403000  .be
# 20            Burkina Faso      854     226    16241811  .bf
# 21                Bulgaria      100     359     7148785  .bg
# 22                 Bahrain       48     973      738004  .bh
# 23                 Burundi      108     257     9863117  .bi
# 24                   Benin      204     229     9056010  .bj
# 27                  Brunei       96     673      395027  .bn

# %% [markdown]
# ### 14) Visualizar a traves de un gráfico de puntos (scatter) la relación entre las caracteristicas AREA (eje x) y POPULATION (eje y) de SUBDF1

# %%
SUBDF1.plot(kind="scatter",x="area", y="population")
# Out:
# <Axes: xlabel='area', ylabel='population'>

# %% [markdown]
# ### 15) Agregar una nueva caracteristica al dataframe SUBDF1 cuyo nombre sea RELACION y sea el resultado de dividir POPULATION/AREA

# %%
SUBDF1["RELACION"]=SUBDF1["population"] / SUBDF1["area"]

# %% [markdown]
# ### 16) Visualizar las 10 primeras observaciones de SUBDF1 y verificar que existe la nueva columna que acabamos de agregar

# %%
SUBDF1.head(10)
# Out:
#    alpha_2 alpha_3       area           capital continent currency_code  \
# 0       AD     AND      468.0  Andorra la Vella        EU           EUR
# 1       AE     ARE    82880.0         Abu Dhabi        AS           AED
# 2       AF     AFG   647500.0             Kabul        AS           AFN
# 5       AL     ALB    28748.0            Tirana        EU           ALL
# 6       AM     ARM    29800.0           Yerevan        AS           AMD
# 7       AO     AGO  1246700.0            Luanda        AF           AOA
# 9       AR     ARG  2766890.0      Buenos Aires        SA           ARS
# 10      AS     ASM      199.0         Pago Pago        OC           USD
# 11      AT     AUT    83858.0            Vienna        EU           EUR
# 12      AU     AUS  7686850.0          Canberra        OC           AUD
#
#    currency_name fips  geoname_id             languages                  name  \
# 0           Euro   AN     3041565                    ca               Andorra
# 1         Dirham   AE      290557     ar-AE,fa,en,hi,ur  United Arab Emirates
# 2        Afghani   AF     1149361     fa-AF,ps,uz-AF,tk           Afghanistan
# 5            Lek   AL      783754                 sq,el               Albania
# 6           Dram   AM      174982                    hy               Armenia
# 7         Kwanza   AO     3351879                 pt-AO                Angola
# 9           Peso   AR     3865483  es-AR,en,it,de,fr,gn             Argentina
# 10        Dollar   AQ     5880801           en-AS,sm,to        American Samoa
# 11          Euro   AU     2782113        de-AT,hr,hu,sl               Austria
# 12        Dollar   AS     2077456                 en-AU             Australia
#
#     numeric   phone  population  tld    RELACION
# 0        20     376       84000  .ad  179.487179
# 1       784     971     4975593  .ae   60.033699
# 2         4      93    29121286  .af   44.974959
# 5         8     355     2986952  .al  103.901211
# 6        51     374     2968000  .am   99.597315
# 7        24     244    13068161  .ao   10.482202
# 9        32      54    41343201  .ar   14.942119
# 10       16  +1-684       57881  .as  290.859296
# 11       40      43     8205000  .at   97.843974
# 12       36      61    21515754  .au    2.799034

# %% [markdown]
# ### EJECUTAR LAS SIGUIENTES CELDAS

# %%
#EJECUTE ESTE CODIGO PARA VER CUANTOS VALORES ÚNICOS HAY EN LA CARACTERISTICA CONTINENT DE 
SUBDF1["continent"].unique()
#array(['EU', 'AS',  'AF',  'SA', 'OC'], dtype=object)
# Out:
# array(['EU', 'AS', 'AF', 'SA', 'OC'], dtype=object)

# %%
#EJECUTE ESTE CODIGO PARA CREAR UN DATAFRAME CON EL CODIGO Y NOMBRE DE CADA UNO DE LOS CON
Continent=['EU', 'AS',  'AF',  'SA', 'OC']
Nombre=['EUROPA', 'ASIA', 'AFRICA', 'SUDAMERICA', 'OCEANIA' ]
dataC=pd.DataFrame(
	{'Continent': Continent,
	'Nombre': Nombre}
)
dataC.head()
# Out:
#   Continent      Nombre
# 0        EU      EUROPA
# 1        AS        ASIA
# 2        AF      AFRICA
# 3        SA  SUDAMERICA
# 4        OC     OCEANIA

# %% [markdown]
# ### 17) Hacer un JOIN de tipo INNER entre los dataframes SUBDF1 y DATAC y determine de que forma se podrian relacionar los mismos

# %%
#Se pueden relacionar por continent
dataj=pd.merge(left=SUBDF1, right=dataC,how="inner", left_on="continent", right_on="Continent")

# %% [markdown]
# ### 18) Visualizar las 15 primeras observaciones de DATAJ y verificar que podemos observar ahora el nombre del continente

# %%
dataj.head(15)
# Out:
#    alpha_2 alpha_3      area           capital continent currency_code  \
# 0       AD     AND     468.0  Andorra la Vella        EU           EUR
# 1       AL     ALB   28748.0            Tirana        EU           ALL
# 2       AT     AUT   83858.0            Vienna        EU           EUR
# 3       BA     BIH   51129.0          Sarajevo        EU           BAM
# 4       BE     BEL   30510.0          Brussels        EU           EUR
# 5       BG     BGR  110910.0             Sofia        EU           BGN
# 6       BY     BLR  207600.0             Minsk        EU           BYR
# 7       CH     CHE   41290.0              Bern        EU           CHF
# 8       CY     CYP    9250.0           Nicosia        EU           EUR
# 9       CZ     CZE   78866.0            Prague        EU           CZK
# 10      DE     DEU  357021.0            Berlin        EU           EUR
# 11      DK     DNK   43094.0        Copenhagen        EU           DKK
# 12      EE     EST   45226.0           Tallinn        EU           EUR
# 13      ES     ESP  504782.0            Madrid        EU           EUR
# 14      FI     FIN  337030.0          Helsinki        EU           EUR
#
#    currency_name fips  geoname_id             languages  \
# 0           Euro   AN     3041565                    ca
# 1            Lek   AL      783754                 sq,el
# 2           Euro   AU     2782113        de-AT,hr,hu,sl
# 3          Marka   BK     3277605        bs,hr-BA,sr-BA
# 4           Euro   BE     2802361     nl-BE,fr-BE,de-BE
# 5            Lev   BU      732800          bg,tr-BG,rom
# 6          Ruble   BO      630336                 be,ru
# 7          Franc   SZ     2658434  de-CH,fr-CH,it-CH,rm
# 8           Euro   CY      146669        el-CY,tr-CY,en
# 9         Koruna   EZ     3077311                 cs,sk
# 10          Euro   GM     2921044                    de
# 11         Krone   DA     2623032     da-DK,en,fo,de-DK
# 12          Euro   EN      453733                 et,ru
# 13          Euro   SP     2510769     es-ES,ca,gl,eu,oc
# 14          Euro   FI      660013       fi-FI,sv-FI,smn
#
#                       name  numeric phone  population  tld    RELACION  \
# 0                  Andorra       20   376       84000  .ad  179.487179
# 1                  Albania        8   355     2986952  .al  103.901211
# 2                  Austria       40    43     8205000  .at   97.843974
# 3   Bosnia and Herzegovina       70   387     4590000  .ba   89.772927
# 4                  Belgium       56    32    10403000  .be  340.970174
# 5                 Bulgaria      100   359     7148785  .bg   64.455730
# 6                  Belarus      112   375     9685000  .by   46.652216
# 7              Switzerland      756    41     7581000  .ch  183.603778
# 8                   Cyprus      196   357     1102677  .cy  119.208324
# 9                  Czechia      203   420    10476000  .cz  132.832906
# 10                 Germany      276    49    81802257  .de  229.124497
# 11                 Denmark      208    45     5484000  .dk  127.256695
# 12                 Estonia      233   372     1291170  .ee   28.549286
# 13                   Spain      724    34    46505963  .es   92.130787
# 14                 Finland      246   358     5244000  .fi   15.559446
#
#    Continent  Nombre
# 0         EU  EUROPA
# 1         EU  EUROPA
# 2         EU  EUROPA
# 3         EU  EUROPA
# 4         EU  EUROPA
# 5         EU  EUROPA
# 6         EU  EUROPA
# 7         EU  EUROPA
# 8         EU  EUROPA
# 9         EU  EUROPA
# 10        EU  EUROPA
# 11        EU  EUROPA
# 12        EU  EUROPA
# 13        EU  EUROPA
# 14        EU  EUROPA

# %% [markdown]
# ### 19) Visualizar las 15 ultimas observaciones de DATAJ y verificar que podemos observar ahora el nombre del continente

# %%
dataj.tail(15)
# Out:
#     alpha_2 alpha_3      area       capital continent currency_code  \
# 184      NF     NFK      34.6      Kingston        OC           AUD
# 185      NR     NRU      21.0         Yaren        OC           AUD
# 186      NU     NIU     260.0         Alofi        OC           NZD
# 187      NZ     NZL  268680.0    Wellington        OC           NZD
# 188      PF     PYF    4167.0       Papeete        OC           XPF
# 189      PG     PNG  462840.0  Port Moresby        OC           PGK
# 190      PN     PCN      47.0     Adamstown        OC           NZD
# 191      PW     PLW     458.0      Melekeok        OC           USD
# 192      SB     SLB   28450.0       Honiara        OC           SBD
# 193      TL     TLS   15007.0          Dili        OC           USD
# 194      TO     TON     748.0    Nuku'alofa        OC           TOP
# 195      TV     TUV      26.0      Funafuti        OC           AUD
# 196      VU     VUT   12200.0     Port Vila        OC           VUV
# 197      WF     WLF     274.0      Mata Utu        OC           XPF
# 198      WS     WSM    2944.0          Apia        OC           WST
#
#     currency_name fips  geoname_id                    languages  \
# 184        Dollar   NF     2155115                        en-NF
# 185        Dollar   NR     2110425                     na,en-NR
# 186        Dollar   NE     4036232                    niu,en-NU
# 187        Dollar   NZ     2186224                     en-NZ,mi
# 188         Franc   FP     4030656                     fr-PF,ty
# 189          Kina   PP     2088628             en-PG,ho,meu,tpi
# 190        Dollar   PC     4030699                        en-PN
# 191        Dollar   PS     1559582  pau,sov,en-PW,tox,ja,fil,zh
# 192        Dollar   BP     2103350                    en-SB,tpi
# 193        Dollar   TT     1966436              tet,pt-TL,id,en
# 194       Pa'anga   TN     4032283                     to,en-TO
# 195        Dollar   TV     2110297                tvl,en,sm,gil
# 196          Vatu   NH     2134431               bi,en-VU,fr-VU
# 197         Franc   WF     4034749                wls,fud,fr-WF
# 198          Tala   WS     4034894                     sm,en-WS
#
#                   name  numeric phone  population  tld    RELACION Continent  \
# 184     Norfolk Island      574   672        1828  .nf   52.832370        OC
# 185              Nauru      520   674       10065  .nr  479.285714        OC
# 186               Niue      570   683        2166  .nu    8.330769        OC
# 187        New Zealand      554    64     4252277  .nz   15.826548        OC
# 188   French Polynesia      258   689      270485  .pf   64.911207        OC
# 189   Papua New Guinea      598   675     6064515  .pg   13.102833        OC
# 190           Pitcairn      612   870          46  .pn    0.978723        OC
# 191              Palau      585   680       19907  .pw   43.465066        OC
# 192    Solomon Islands       90   677      559198  .sb   19.655466        OC
# 193         East Timor      626   670     1154625  .tl   76.939095        OC
# 194              Tonga      776   676      122580  .to  163.877005        OC
# 195             Tuvalu      798   688       10472  .tv  402.769231        OC
# 196            Vanuatu      548   678      221552  .vu   18.160000        OC
# 197  Wallis and Futuna      876   681       16025  .wf   58.485401        OC
# 198              Samoa      882   685      192001  .ws   65.217731        OC
#
#       Nombre
# 184  OCEANIA
# 185  OCEANIA
# 186  OCEANIA
# 187  OCEANIA
# 188  OCEANIA
# 189  OCEANIA
# 190  OCEANIA
# 191  OCEANIA
# 192  OCEANIA
# 193  OCEANIA
# 194  OCEANIA
# 195  OCEANIA
# 196  OCEANIA
# 197  OCEANIA
# 198  OCEANIA
